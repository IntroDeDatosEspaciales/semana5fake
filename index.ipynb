# %%
from IPython.display import IFrame  
ciaLink1="https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison" 
#IFrame(ciaLink1, width=900, height=900)

# %%
import pandas as pd

linkToFile='https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv'
carbon=pd.read_csv(linkToFile)

# %%
carbon
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug             value  \
# 0                                          china  10,773,248,000.0
# 1                                  united-states   5,144,361,000.0
# 2                                          india   2,314,738,000.0
# 3                                         russia   1,848,070,000.0
# ...

# %%
#EJERCICIO 2

# %%
from IPython.display import IFrame  
ciaLink2="https://www.cia.gov/the-world-factbook/field/revenue-from-forest-resources/country-comparison" 
IFrame(ciaLink2, width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="https://www.cia.gov/the-world-factbook/field/revenue-from-forest-resources/country-comparison"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# read web table into pandas DF
import pandas as pd

forestDFs=pd.read_html(ciaLink2, # link
                        header=0, # where is the header?
                        flavor='bs4')

# %%
# check object type 
type(forestDFs)
# Out:
# list

# %%
# check size
len(forestDFs)
# Out:
# 1

# %%
# make a copy
forest=forestDFs[0].copy()

# %%
forest
# Out:
#      Rank                   Country  % of GDP Date of Information
# 0       1           Solomon Islands     20.27           2018 est.
# 1       2                   Liberia     13.27           2018 est.
# 2       3                   Burundi     10.31           2018 est.
# 3       4             Guinea-Bissau      9.24           2018 est.
# 4       5  Central African Republic      8.99           2018 est.
# ..    ...                       ...       ...                 ...
# 199   200                      Guam      0.00           2018 est.
# 200   201             Faroe Islands      0.00           2017 est.
# 201   202                     Aruba      0.00           2017 est.
# 202   203            Virgin Islands      0.00           2017 est.
# 203   204                     Macau      0.00           2018 est.
#
# [204 rows x 4 columns]

# %%
forest.columns
# Out:
# Index(['Rank', 'Country', '% of GDP', 'Date of Information'], dtype='object')

# %%
forest.columns.to_list()
# Out:
# ['Rank', 'Country', '% of GDP', 'Date of Information']

# %%
forest['Date of Information'].value_counts()
# Out:
# Date of Information
# 2018 est.    195
# 2017 est.      7
# 2015 est.      1
# 2016 est.      1
# Name: count, dtype: int64

# %%
#1 Replace '%' by 'pct'.
forest.columns=forest.columns.str.replace(pat=r'%',repl='pct',regex=True)
forest
# Out:
#      Rank                   Country  pct of GDP Date of Information
# 0       1           Solomon Islands       20.27           2018 est.
# 1       2                   Liberia       13.27           2018 est.
# 2       3                   Burundi       10.31           2018 est.
# 3       4             Guinea-Bissau        9.24           2018 est.
# 4       5  Central African Republic        8.99           2018 est.
# ..    ...                       ...         ...                 ...
# 199   200                      Guam        0.00           2018 est.
# 200   201             Faroe Islands        0.00           2017 est.
# 201   202                     Aruba        0.00           2017 est.
# 202   203            Virgin Islands        0.00           2017 est.
# 203   204                     Macau        0.00           2018 est.
#
# [204 rows x 4 columns]

# %%
#2 mantener el nombre de columnas y quitar el rank
forest=forest.drop(columns=['Rank'])
forest
# Out:
#                       Country  pct of GDP Date of Information
# 0             Solomon Islands       20.27           2018 est.
# 1                     Liberia       13.27           2018 est.
# 2                     Burundi       10.31           2018 est.
# 3               Guinea-Bissau        9.24           2018 est.
# 4    Central African Republic        8.99           2018 est.
# ..                        ...         ...                 ...
# 199                      Guam        0.00           2018 est.
# 200             Faroe Islands        0.00           2017 est.
# 201                     Aruba        0.00           2017 est.
# 202            Virgin Islands        0.00           2017 est.
# 203                     Macau        0.00           2018 est.
#
# [204 rows x 3 columns]

# %%
#3
forest=forest.rename(columns={"Date of Information": "forest_date"})
forest
# Out:
#                       Country  pct of GDP forest_date
# 0             Solomon Islands       20.27   2018 est.
# 1                     Liberia       13.27   2018 est.
# 2                     Burundi       10.31   2018 est.
# 3               Guinea-Bissau        9.24   2018 est.
# 4    Central African Republic        8.99   2018 est.
# ..                        ...         ...         ...
# 199                      Guam        0.00   2018 est.
# 200             Faroe Islands        0.00   2017 est.
# 201                     Aruba        0.00   2017 est.
# 202            Virgin Islands        0.00   2017 est.
# 203                     Macau        0.00   2018 est.
#
# [204 rows x 3 columns]

# %%
#4 no debe existir espacio entre el nombre de las columnas
forest.columns=forest.columns.str.replace(pat=r' ',repl='',regex=True)
forest
# Out:
#                       Country  pctofGDP forest_date
# 0             Solomon Islands     20.27   2018 est.
# 1                     Liberia     13.27   2018 est.
# 2                     Burundi     10.31   2018 est.
# 3               Guinea-Bissau      9.24   2018 est.
# 4    Central African Republic      8.99   2018 est.
# ..                        ...       ...         ...
# 199                      Guam      0.00   2018 est.
# 200             Faroe Islands      0.00   2017 est.
# 201                     Aruba      0.00   2017 est.
# 202            Virgin Islands      0.00   2017 est.
# 203                     Macau      0.00   2018 est.
#
# [204 rows x 3 columns]

# %%
#5
forest['Country']=forest['Country'].str.strip()
forest
# Out:
#                       Country  pctofGDP forest_date
# 0             Solomon Islands     20.27   2018 est.
# 1                     Liberia     13.27   2018 est.
# 2                     Burundi     10.31   2018 est.
# 3               Guinea-Bissau      9.24   2018 est.
# 4    Central African Republic      8.99   2018 est.
# ..                        ...       ...         ...
# 199                      Guam      0.00   2018 est.
# 200             Faroe Islands      0.00   2017 est.
# 201                     Aruba      0.00   2017 est.
# 202            Virgin Islands      0.00   2017 est.
# 203                     Macau      0.00   2018 est.
#
# [204 rows x 3 columns]

# %%
#6
forest.forest_date.str.extract(pat=r'(\d+)',expand=True)
# Out:
#         0
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# ..    ...
# 199  2018
# 200  2017
# 201  2017
# 202  2017
# 203  2018
#
# [204 rows x 1 columns]

# %%
#TERMINADO EJERCICIO 2

# %%
#EJERCICIO 1

# %%
from IPython.display import IFrame  
ciaLink1="https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison" 
#IFrame(ciaLink1, width=900, height=900)

# %%
# read web table into pandas DF
import pandas as pd

linkToFile='https://github.com/CienciaDeDatosEspacial/code_and_data/raw/main/data/carbonEmi_downloaded.csv'
carbon=pd.read_csv(linkToFile)

# %%
carbon
# Out:
#                                               name  \
# 0                                            China
# 1                                    United States
# 2                                            India
# 3                                           Russia
# 4                                            Japan
# ..                                             ...
# 213                                     Antarctica
# 214  Saint Helena, Ascension, and Tristan da Cunha
# 215                                           Niue
# 216                       Northern Mariana Islands
# 217                                         Tuvalu
#
#                                             slug             value  \
# 0                                          china  10,773,248,000.0
# 1                                  united-states   5,144,361,000.0
# 2                                          india   2,314,738,000.0
# 3                                         russia   1,848,070,000.0
# ...

# %%
import pandas as pd
carbon=pd.DataFrame(carbon)

# %%
carbon=carbon.drop(columns=["slug", "ranking"])
carbon
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     date_of_information                   region
# 0             2019 est.  East and Southeast Asia
# ...

# %%
# Change the column name date_of_information to carbon_date
carbon=carbon.rename(columns={"date_of_information": "carbon_date"})
carbon
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
#Make sure the cells with text does not have neither trailing nor leading spaces
carbon['name'] = carbon['name'].str.strip()
carbon
# Out:
#                                               name             value  \
# 0                                            China  10,773,248,000.0
# 1                                    United States   5,144,361,000.0
# 2                                            India   2,314,738,000.0
# 3                                           Russia   1,848,070,000.0
# 4                                            Japan   1,103,234,000.0
# ..                                             ...               ...
# 213                                     Antarctica          28,000.0
# 214  Saint Helena, Ascension, and Tristan da Cunha          13,000.0
# 215                                           Niue           8,000.0
# 216                       Northern Mariana Islands               0.0
# 217                                         Tuvalu               0.0
#
#     carbon_date                   region
# 0     2019 est.  East and Southeast Asia
# 1     2019 est.            North America
# ...

# %%
# Detect the presence of symbols in the numeric data that are not numeric or point
carbon.value.str.contains(pat=r'\D',regex=True)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 213    True
# 214    True
# 215    True
# 216    True
# 217    True
# Name: value, Length: 218, dtype: bool

# %%
#Keep only the year value in the column carbon_date
carbon.carbon_date.str.extract(pat=r'(\d+)',expand=True)
# Out:
#         0
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# 4    2019
# ..    ...
# 213  2019
# 214  2019
# 215  2019
# 216  2019
# 217  2019
#
# [218 rows x 1 columns]
